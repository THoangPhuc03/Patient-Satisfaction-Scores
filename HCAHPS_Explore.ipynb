# %% [markdown]
# # Data Exploration

# %% [markdown]
# For HCAHPS_data

# %%
import pandas as pd

data = pd.read_csv('/content/drive/MyDrive/HCAHPS Patient Satisfacetion Scores/HCAHPS_data.csv')

# %%
data.head()
# Out:
#   Facility ID                    Facility Name                 Address  \
# 0      010001  SOUTHEAST HEALTH MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 1      010001  SOUTHEAST HEALTH MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 2      010001  SOUTHEAST HEALTH MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 3      010001  SOUTHEAST HEALTH MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 4      010001  SOUTHEAST HEALTH MEDICAL CENTER  1108 ROSS CLARK CIRCLE
#
#   City/Town State  ZIP Code County/Parish Telephone Number  \
# 0    DOTHAN    AL     36301       HOUSTON   (334) 793-8701
# 1    DOTHAN    AL     36301       HOUSTON   (334) 793-8701
# 2    DOTHAN    AL     36301       HOUSTON   (334) 793-8701
# 3    DOTHAN    AL     36301       HOUSTON   (334) 793-8701
# 4    DOTHAN    AL     36301       HOUSTON   (334) 793-8701
#
#        HCAHPS Measure ID                                    HCAHPS Question  \
# 0           H_COMP_1_A_P  Patients who reported that their nurses "Alway...
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 443517 entries, 0 to 443516
# Data columns (total 16 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   Facility ID                   443517 non-null  object
#  1   Facility Name                 443517 non-null  object
#  2   Address                       443517 non-null  object
#  3   City/Town                     443517 non-null  object
#  4   State                         443517 non-null  object
#  5   ZIP Code                      443517 non-null  int64
#  6   County/Parish                 443517 non-null  object
#  7   Telephone Number              443517 non-null  object
#  8   HCAHPS Measure ID             443517 non-null  object
#  9   HCAHPS Question               443517 non-null  object
#  10  HCAHPS Answer Description     443517 non-null  object
#  11  HCAHPS Answer Percent         443517 non-null  object
# ...

# %% [markdown]
# So this data don't have any null but i noticed that three columns, **HCAHPS Answer Percent, Number of Completed Surveys, and Survey Response Rate Percent**, should be either float or int, but they are recognized as objects.
#
# Something seems off, so I decided to investigate.

# %%
data['HCAHPS Answer Percent'].unique()
# Out:
# array(['72', '6', '22', 'Not Applicable', '82', '3', '15', '67', '8',
#        '25', '68', '7', '79', '4', '17', '84', '12', '77', '19', '75',
#        '5', '20', '57', '28', '54', '31', '16', '27', '56', '23', '21',
#        '10', '18', '40', '35', '85', '14', '86', '44', '9', '47', '60',
#        '64', '65', '29', '71', '74', '73', '81', '11', '80', '78', '53',
#        '30', '50', '32', '61', '45', '34', '13', '87', '90', '49', '39',
#        '69', '26', '63', '70', '83', '52', '51', '41', '36', '1', '2',
#        '89', '92', '91', '93', '46', '55', '58', 'Not Available', '0',
#        '24', '76', '62', '43', '48', '38', '66', '59', '33', '94', '88',
#        '96', '42', '37', '95', '97', '98', '100', '99'], dtype=object)

# %%
data['Number of Completed Surveys'].unique()
# Out:
# array(['684', '667', '1642', ..., '897', '1217', '2429'], dtype=object)

# %%
non_numeric = pd.to_numeric(data['Number of Completed Surveys'], errors='coerce').isna()
non_numeric_words = data[non_numeric & data['Number of Completed Surveys'].notna()]['Number of Completed Surveys'].unique()
print(non_numeric_words)
# Out:
# ['Not Available']

# %%
data['HCAHPS Answer Percent'].unique()
# Out:
# array(['72', '6', '22', 'Not Applicable', '82', '3', '15', '67', '8',
#        '25', '68', '7', '79', '4', '17', '84', '12', '77', '19', '75',
#        '5', '20', '57', '28', '54', '31', '16', '27', '56', '23', '21',
#        '10', '18', '40', '35', '85', '14', '86', '44', '9', '47', '60',
#        '64', '65', '29', '71', '74', '73', '81', '11', '80', '78', '53',
#        '30', '50', '32', '61', '45', '34', '13', '87', '90', '49', '39',
#        '69', '26', '63', '70', '83', '52', '51', '41', '36', '1', '2',
#        '89', '92', '91', '93', '46', '55', '58', 'Not Available', '0',
#        '24', '76', '62', '43', '48', '38', '66', '59', '33', '94', '88',
#        '96', '42', '37', '95', '97', '98', '100', '99'], dtype=object)

# %% [markdown]
# Now i can see what going on here. I will modified it later in SQL

# %% [markdown]
# Let's do similar thing with Hospital_beds

# %%
data_2 = pd.read_csv('/content/drive/MyDrive/HCAHPS Patient Satisfacetion Scores/Hospital_beds.csv')

# %%
data_2.head()
# Out:
#   PRVDR_NUM                               FAC_NAME  CRTFD_BED_CNT
# 0    010001        SOUTHEAST HEALTH MEDICAL CENTER            420
# 1    010004                 NORTH JACKSON HOSPITAL             64
# 2    010005  MARSHALL MEDICAL CENTERS SOUTH CAMPUS            240
# 3    010006           NORTH ALABAMA MEDICAL CENTER            338
# 4    010007               MIZELL MEMORIAL HOSPITAL             99

# %%
data_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64311 entries, 0 to 64310
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   PRVDR_NUM      64311 non-null  object
#  1   FAC_NAME       64311 non-null  object
#  2   CRTFD_BED_CNT  64311 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 1.5+ MB

# %% [markdown]
# This data is clean. It ok to go to the next step.
